# %% [markdown]
# <a href="https://colab.research.google.com/github/BahmanFalahpour/BF3-Trading-Style/blob/main/notebooks/so-vits-svc-fork-4.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Before training
#
# This program saves the last 3 generations of models to Google Drive. Since 1 generation of models is >1GB, you should have at least 3GB of free space in Google Drive. If you do not have such free space, it is recommended to create another Google Account.

# %% [markdown]
# ## Installation

# %%
# @title Check GPU
# !nvidia-smi
# Out:
# Tue Dec 23 17:22:49 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# @title Mount Google Drive
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# @title Install dependencies
# @markdown pip may fail to resolve dependencies and raise ERROR, but it can be ignored.
# !python -m pip install -U pip wheel
# %pip install -U ipython

# @markdown Branch (for development)
BRANCH = "none"  # @param {"type": "string"}
if BRANCH == "none":
    # %pip install -U so-vits-svc-fork
else:
    # %pip install -U git+https://github.com/34j/so-vits-svc-fork.git@{BRANCH}
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (25.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.45.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (9.8.0)
# Requirement already satisfied: decorator>=4.3.2 in /usr/local/lib/python3.12/dist-packages (from ipython) (4.4.2)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /usr/local/lib/python3.12/dist-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from ipython) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.12/dist-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /usr/local/lib/python3.12/dist-packages (from ipython) (5.14.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.18.1->ipython) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from stack_data>=0.6.0->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from stack_data>=0.6.0->ipython) (3.0.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.12/dist-packages (from stack_data>=0.6.0->ipython) (0.2.3)
# Requirement already satisfied: so-vits-svc-fork in /usr/local/lib/python3.12/dist-packages (4.2.29)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (8.3.1)
# Requirement already satisfied: cm-time>=0.1.2 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (0.1.2)
# Requirement already satisfied: fastapi>=0.116.1 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (0.123.10)
# Requirement already satisfied: librosa>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (0.11.0)
# Requirement already satisfied: lightning>=2.5.5 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (2.6.0)
# Requirement already satisfied: matplotlib>=3.9.4 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (3.10.0)
# Requirement already satisfied: numpy>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (2.0.2)
# Requirement already satisfied: pebble>=5.1.3 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (5.1.3)
# Requirement already satisfied: praat-parselmouth>=0.4.6 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (0.4.7)
# Requirement already satisfied: psutil>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (7.1.3)
# Requirement already satisfied: pysimplegui-4-foss>=4.60.4.1 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (4.60.4.1)
# Requirement already satisfied: pyworld>=0.3.5 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (0.3.5)
# Requirement already satisfied: requests>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (2.32.5)
# Requirement already satisfied: rich>=14.1.0 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (14.2.0)
# Requirement already satisfied: scipy>=1.13.1 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (1.16.3)
# Requirement already satisfied: sounddevice>=0.5.2 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (0.5.3)
# Requirement already satisfied: soundfile>=0.13.1 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (0.13.1)
# Requirement already satisfied: tensorboard>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (2.20.0)
# Requirement already satisfied: tensorboardx>=2.6.4 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (2.6.4)
# Requirement already satisfied: torch>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (2.9.0+cu126)
# Requirement already satisfied: torchaudio>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (2.9.0+cu126)
# Requirement already satisfied: torchcrepe>=0.0.24 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (0.0.24)
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (4.67.1)
# Requirement already satisfied: tqdm-joblib>=0.0.4 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (0.0.5)
# Requirement already satisfied: transformers>=4.56.1 in /usr/local/lib/python3.12/dist-packages (from so-vits-svc-fork) (4.57.3)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.116.1->so-vits-svc-fork) (0.50.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.116.1->so-vits-svc-fork) (2.12.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.116.1->so-vits-svc-fork) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.116.1->so-vits-svc-fork) (0.0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi>=0.116.1->so-vits-svc-fork) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi>=0.116.1->so-vits-svc-fork) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi>=0.116.1->so-vits-svc-fork) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette<0.51.0,>=0.40.0->fastapi>=0.116.1->so-vits-svc-fork) (4.12.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi>=0.116.1->so-vits-svc-fork) (3.11)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.11.0->so-vits-svc-fork) (1.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lazy_loader>=0.1->librosa>=0.11.0->so-vits-svc-fork) (25.0)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.5.5->so-vits-svc-fork) (6.0.3)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (2025.3.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.5.5->so-vits-svc-fork) (0.15.2)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.5.5->so-vits-svc-fork) (1.8.2)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning>=2.5.5->so-vits-svc-fork) (2.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (3.13.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning>=2.5.5->so-vits-svc-fork) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.8.0->so-vits-svc-fork) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.5.5->so-vits-svc-fork) (1.22.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->so-vits-svc-fork) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->so-vits-svc-fork) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->so-vits-svc-fork) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->so-vits-svc-fork) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->so-vits-svc-fork) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->so-vits-svc-fork) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.4->so-vits-svc-fork) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa>=0.11.0->so-vits-svc-fork) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa>=0.11.0->so-vits-svc-fork) (4.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.9.4->so-vits-svc-fork) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->so-vits-svc-fork) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->so-vits-svc-fork) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->so-vits-svc-fork) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=14.1.0->so-vits-svc-fork) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=14.1.0->so-vits-svc-fork) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=14.1.0->so-vits-svc-fork) (0.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa>=0.11.0->so-vits-svc-fork) (3.6.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.12/dist-packages (from sounddevice>=0.5.2->so-vits-svc-fork) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from CFFI>=1.0->sounddevice>=0.5.2->so-vits-svc-fork) (2.23)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.8.0->so-vits-svc-fork) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->so-vits-svc-fork) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->so-vits-svc-fork) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->so-vits-svc-fork) (3.10)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->so-vits-svc-fork) (5.29.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->so-vits-svc-fork) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->so-vits-svc-fork) (3.1.4)
# Requirement already satisfied: resampy in /usr/local/lib/python3.12/dist-packages (from torchcrepe>=0.0.24->so-vits-svc-fork) (0.4.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.1->so-vits-svc-fork) (0.36.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.1->so-vits-svc-fork) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.1->so-vits-svc-fork) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.1->so-vits-svc-fork) (0.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.56.1->so-vits-svc-fork) (1.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.20.0->so-vits-svc-fork) (3.0.3)

# %% [markdown]
# ## Training

# %%
# @title Make dataset directory
# !mkdir -p "dataset_raw"

# %%
# @title Copy your dataset
# @markdown **We assume that your dataset is in your Google Drive's `so-vits-svc-fork/dataset/(speaker_name)` directory.**
DATASET_NAME = "kiritan"  # @param {type: "string"}
# !cp -R /content/drive/MyDrive/so-vits-svc-fork/dataset/{DATASET_NAME}/ -t "dataset_raw/"

# %%
# @title Download dataset (Tsukuyomi-chan JVS)
# @markdown You can download this dataset if you don't have your own dataset.
# @markdown Make sure you agree to the license when using this dataset.
# @markdown https://tyc.rei-yumesaki.net/material/corpus/#toc6
# !wget -N https://tyc.rei-yumesaki.net/files/voice/tyc-corpus1.zip
# !unzip -O sjis tyc-corpus1.zip
# !mv "/content/つくよみちゃんコーパス Vol.1 声優統計コーパス（JVSコーパス準拠）/おまけ：WAV（+12dB増幅＆高音域削減）/WAV（+12dB増幅＆高音域削減）" "dataset_raw/tsukuyomi"

# %%
# @title Automatic preprocessing
# !svc pre-resample

# %%
# !svc pre-config

# %%
F0_METHOD = "dio"  # @param ["crepe", "crepe-tiny", "parselmouth", "dio", "harvest"]
# !svc pre-hubert -fm {F0_METHOD}

# %%
# @title Train
# %load_ext tensorboard
# %tensorboard --logdir drive/MyDrive/so-vits-svc-fork/logs/44k

# %%
# !svc train --model-path drive/MyDrive/so-vits-svc-fork/logs/44k

# %% [markdown]
# ## Training Cluster model

# %%
# !svc train-cluster --output-path drive/MyDrive/so-vits-svc-fork/logs/44k/kmeans.pt

# %% [markdown]
# ## Inference

# %%
# @title Get the author's voice as a source
import random

NAME = str(random.randint(1, 49))
TYPE = "fsd50k"  # @param ["", "digit", "dog", "fsd50k"]
CUSTOM_FILEPATH = ""  # @param {type: "string"}
if CUSTOM_FILEPATH != "":
    NAME = CUSTOM_FILEPATH
else:
    # it is extremely difficult to find a voice that can download from the internet directly
    if TYPE == "dog":
        # !wget -N f"https://huggingface.co/datasets/437aewuh/dog-dataset/resolve/main/dogs/dogs_{NAME:.0000}.wav" -O {NAME}.wav
    elif TYPE == "digit":
        # george, jackson, lucas, nicolas, ...
        # !wget -N f"https://github.com/Jakobovski/free-spoken-digit-dataset/raw/master/recordings/0_george_{NAME}.wav" -O {NAME}.wav
    elif TYPE == "fsd50k":
        # !wget -N f"https://huggingface.co/datasets/Fhrozen/FSD50k/blob/main/clips/dev/{10000+int(NAME)}.wav" -O {NAME}.wav
    else:
        # !wget -N f"https://zunko.jp/sozai/utau/voice_{"kiritan" if NAME < 25 else "itako"}{NAME % 5 + 1}.wav" -O {NAME}.wav
from IPython.display import Audio, display

display(Audio(f"{NAME}.wav"))

# %%
# @title Use trained model
# @markdown **Put your .wav file in `so-vits-svc-fork/audio` directory**
from IPython.display import Audio, display

# !svc infer drive/MyDrive/so-vits-svc-fork/audio/{NAME}.wav -m drive/MyDrive/so-vits-svc-fork/logs/44k/ -c drive/MyDrive/so-vits-svc-fork/logs/44k/config.json
display(Audio(f"drive/MyDrive/so-vits-svc-fork/audio/{NAME}.out.wav", autoplay=True))

# %%
##@title Use trained model (with cluster)
# !svc infer {NAME}.wav -s speaker -r 0.1 -m drive/MyDrive/so-vits-svc-fork/logs/44k/ -c drive/MyDrive/so-vits-svc-fork/logs/44k/config.json -k drive/MyDrive/so-vits-svc-fork/logs/44k/kmeans.pt
display(Audio(f"{NAME}.out.wav", autoplay=True))

# %% [markdown]
# ### Pretrained models

# %%
# @title https://huggingface.co/TachibanaKimika/so-vits-svc-4.0-models/tree/main
# !wget -N "https://huggingface.co/TachibanaKimika/so-vits-svc-4.0-models/resolve/main/riri/G_riri_220.pth"
# !wget -N "https://huggingface.co/TachibanaKimika/so-vits-svc-4.0-models/resolve/main/riri/config.json"

# %%
# !svc infer {NAME}.wav -c config.json -m G_riri_220.pth
display(Audio(f"{NAME}.out.wav", autoplay=True))

# %%
# @title https://huggingface.co/therealvul/so-vits-svc-4.0/tree/main
# !wget -N "https://huggingface.co/therealvul/so-vits-svc-4.0/resolve/main/Pinkie%20(speaking%20sep)/G_166400.pth"
# !wget -N "https://huggingface.co/therealvul/so-vits-svc-4.0/resolve/main/Pinkie%20(speaking%20sep)/config.json"

# %%
# !svc infer {NAME}.wav --speaker "Pinkie {neutral}" -c config.json -m G_166400.pth
display(Audio(f"{NAME}.out.wav", autoplay=True))
